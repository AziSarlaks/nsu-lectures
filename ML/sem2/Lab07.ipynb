# %%
# Импорты
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons, make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from matplotlib.colors import ListedColormap

# Настройка стиля графиков
plt.style.use('seaborn-v0_8')

# %%
# Подготовка данных
# Генерируем два полумесяца (нелинейная задача)
X, y = make_moons(n_samples=300, noise=0.2, random_state=42)

# Преобразуем метки 0 в -1 для удобства метода потенциальных функций
y = np.where(y == 0, -1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Визуализация данных
plt.figure(figsize=(8, 6))
plt.scatter(X_train[y_train == 1, 0], X_train[y_train == 1, 1], color='blue', label='Класс +1')
plt.scatter(X_train[y_train == -1, 0], X_train[y_train == -1, 1], color='red', label='Класс -1')
plt.title("Обучающая выборка")
plt.legend()
plt.show()

# %%
class ParzenWindowClassifier:
    def __init__(self, h=0.5, kernel='gaussian'):
        self.h = h
        self.kernel_type = kernel
        self.X_train = None
        self.y_train = None
        self.classes = None

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y
        self.classes = np.unique(y)

    def _gaussian_kernel(self, distance):
        return (1 / (np.sqrt(2 * np.pi))) * np.exp(-0.5 * (distance ** 2))

    def predict_proba(self, X):
        # Вычисляем плотности для каждого класса
        probs = np.zeros((X.shape[0], len(self.classes)))

        for idx, cls in enumerate(self.classes):
            X_cls = self.X_train[self.y_train == cls]

            # Для каждой точки из X считаем сумму ядер от точек обучающей выборки
            for i, x_query in enumerate(X):
                # Евклидово расстояние
                dists = np.linalg.norm(X_cls - x_query, axis=1)
                # Применяем ядро с шириной h
                kernel_vals = self._gaussian_kernel(dists / self.h)
                # Суммируем вклады (без нормировки на N*h, так как сравниваем классы между собой)
                probs[i, idx] = np.sum(kernel_vals)

        return probs

    def predict(self, X):
        probs = self.predict_proba(X)
        return self.classes[np.argmax(probs, axis=1)]

# Вспомогательная функция для отрисовки границ
def plot_decision_boundary(clf, X, y, title="", class_labels=None):
    if class_labels is None:
        class_labels = np.unique(y)
    h = .05  # шаг сетки
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    cmap = ListedColormap(['#FFAAAA', '#AAAAFF'])
    plt.contourf(xx, yy, Z, alpha=0.3, cmap=cmap)
    colors = ['red', 'blue']
    for i, label in enumerate(class_labels):
        plt.scatter(X[y == label, 0], X[y == label, 1], c=colors[i], edgecolors='k', label=str(label))
    plt.title(title)
    plt.legend()
    plt.show()

# %%
# Тестирование Парзеновского окна с разной шириной h
h_values = [0.1, 0.5, 1.5]

plt.figure(figsize=(15, 5))

for i, h in enumerate(h_values):
    clf = ParzenWindowClassifier(h=h)
    clf.fit(X_train, y_train)

    plt.subplot(1, 3, i+1)

    # Копируем логику plot_decision_boundary сюда для subplots
    xx_min, xx_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    yy_min, yy_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(xx_min, xx_max, 0.05),
                         np.arange(yy_min, yy_max, 0.05))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.3, cmap=ListedColormap(['#FFAAAA', '#AAAAFF']))
    plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=ListedColormap(['#FF0000', '#0000FF']), edgecolors='k')
    plt.title(f'Парзеновское окно (h={h})')

plt.tight_layout()
plt.show()

# %%
class PotentialFunctionClassifier:
    def __init__(self, h=1.0, epochs=10):
        self.h = h
        self.epochs = epochs
        self.support_vectors_ = []
        self.charges_ = []
        self.classes = None

    def _kernel(self, u):
        return np.exp(-1 * (u ** 2))

    def fit(self, X, y):
        self.classes = np.unique(y)
        n_samples = X.shape[0]
        self.support_vectors_ = []
        self.charges_ = []

        for epoch in range(self.epochs):
            errors = 0
            for i in range(n_samples):
                x_curr = X[i]
                y_true = y[i]

                decision_val = self._decision_function_single(x_curr)
                y_pred = self.classes[1] if decision_val > 0 else self.classes[0]

                if y_pred != y_true:
                    charge = 1 if y_true == self.classes[1] else -1
                    self.support_vectors_.append(x_curr)
                    self.charges_.append(charge)
                    errors += 1

            if errors == 0:
                print(f"Convergence reached at epoch {epoch}")
                break

    def _decision_function_single(self, x):
        if not self.support_vectors_:
            return 0

        support_vectors = np.array(self.support_vectors_)
        charges = np.array(self.charges_)

        dists = np.linalg.norm(support_vectors - x, axis=1)
        kernels = self._kernel(dists / self.h)
        return np.sum(charges * kernels)

    def predict(self, X):
        preds = []
        for x in X:
            val = self._decision_function_single(x)
            pred = self.classes[1] if val > 0 else self.classes[0]
            preds.append(pred)
        return np.array(preds)

# %%
pot_clf = PotentialFunctionClassifier(h=1.5, epochs=20)
pot_clf.fit(X_train, y_train)

print(f"Количество накопленных потенциалов (корректировок): {len(pot_clf.charges_)}")

# Визуализация
plt.figure(figsize=(8, 6))
plot_decision_boundary(pot_clf, X_test, y_test, title="Метод Потенциальных Функций (Test set)")
# Out:
# Количество накопленных потенциалов (корректировок): 431

# %% [markdown]
# # Лабораторная работа
#
# Применить метод Парзеновского окна и метод Потенциальных функций для решения задачи медицинской диагностики (Диагностика рака груди), подобрать оптимальные гиперпараметры и визуализировать границы принятия решений (Границы отрисовывать для двух самых значимых признаков).
#
# Датасет: sklearn.datasets.load_breast_cancer.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from matplotlib.colors import ListedColormap

# Настройки графиков
plt.style.use('seaborn-v0_8')

# %%
# Загрузка данных
data = load_breast_cancer()
X_raw, y_raw = data.data, data.target

# %%
# Предобработка
# Метрические методы критичны к масштабу, поэтому StandardScaling обязателен
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_raw)

# %%
# Понижение размерности до 2D для визуализации
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print(f"Доля объясненной дисперсии 2 компонентами: {np.sum(pca.explained_variance_ratio_):.2f}")
# Out:
# Доля объясненной дисперсии 2 компонентами: 0.63

# %%
# Разделение на train/test
# Stratify сохраняет баланс классов
X_train, X_test, y_train, y_test = train_test_split(
    X_pca, y_raw, test_size=0.3, random_state=42, stratify=y_raw
)

# %%
# Визуализация датасета в 2D
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='coolwarm', edgecolor='k', alpha=0.7)
plt.legend(handles=scatter.legend_elements()[0], labels=['Malignant (0)', 'Benign (1)'])
plt.title("Breast Cancer Dataset (PCA projection)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Выбор двух наиболее значимых признаков
selector = SelectKBest(score_func=f_classif, k=2)
X_selected = selector.fit_transform(X_scaled, y_raw)
selected_features = selector.get_support(indices=True)
print("Selected features:", data.feature_names[selected_features])

# Разделение на train/test для выбранных признаков
X_train, X_test, y_train, y_test = train_test_split(
    X_selected, y_raw, test_size=0.3, random_state=42, stratify=y_raw
)
# Out:
# Selected features: ['worst perimeter' 'worst concave points']

# %%
# Подбор гиперпараметра h для Парзеновского окна
h_values = [0.1, 0.5, 1.0, 2.0]
accuracies_parzen = []

for h in h_values:
    clf = ParzenWindowClassifier(h=h)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    accuracies_parzen.append(acc)
    print(f"h={h}: accuracy={acc:.3f}")

best_h_parzen = h_values[np.argmax(accuracies_parzen)]
print(f"Best h for Parzen Window: {best_h_parzen}, accuracy: {max(accuracies_parzen):.3f}")
# Out:
# h=0.1: accuracy=0.918
# h=0.5: accuracy=0.918
# h=1.0: accuracy=0.930
# h=2.0: accuracy=0.789
# Best h for Parzen Window: 1.0, accuracy: 0.930
# h=1.0: accuracy=0.930
# h=2.0: accuracy=0.789
# Best h for Parzen Window: 1.0, accuracy: 0.930

# %%
# Подбор гиперпараметров для метода потенциальных функций
h_values = [0.5, 1.0, 1.5, 2.0]
epochs_values = [10, 20, 50]
best_acc_pot = 0
best_h_pot = None
best_epochs_pot = None

for h in h_values:
    for epochs in epochs_values:
        clf = PotentialFunctionClassifier(h=h, epochs=epochs)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        if acc > best_acc_pot:
            best_acc_pot = acc
            best_h_pot = h
            best_epochs_pot = epochs
        print(f"h={h}, epochs={epochs}: accuracy={acc:.3f}")

print(f"Best for Potential Functions: h={best_h_pot}, epochs={best_epochs_pot}, accuracy: {best_acc_pot:.3f}")
# Out:
# h=0.5, epochs=10: accuracy=0.901
# h=0.5, epochs=20: accuracy=0.906
# h=0.5, epochs=20: accuracy=0.906
# h=0.5, epochs=50: accuracy=0.912
# h=1.0, epochs=10: accuracy=0.895
# h=0.5, epochs=50: accuracy=0.912
# h=1.0, epochs=10: accuracy=0.895
# h=1.0, epochs=20: accuracy=0.906
# h=1.0, epochs=20: accuracy=0.906
# h=1.0, epochs=50: accuracy=0.912
# h=1.5, epochs=10: accuracy=0.906
# h=1.0, epochs=50: accuracy=0.912
# h=1.5, epochs=10: accuracy=0.906
# h=1.5, epochs=20: accuracy=0.883
# h=1.5, epochs=20: accuracy=0.883
# h=1.5, epochs=50: accuracy=0.918
# h=2.0, epochs=10: accuracy=0.854
# h=1.5, epochs=50: accuracy=0.918
# h=2.0, epochs=10: accuracy=0.854
# h=2.0, epochs=20: accuracy=0.930
# h=2.0, epochs=20: accuracy=0.930
# h=2.0, epochs=50: accuracy=0.871
# Best for Potential Functions: h=2.0, epochs=20, accuracy: 0.930
# h=2.0, epochs=50: accuracy=0.871
# Best for Potential Functions: h=2.0, epochs=20, accuracy: 0.930

# %%
# Визуализация границы принятия решений для Парзеновского окна
clf_parzen = ParzenWindowClassifier(h=best_h_parzen)
clf_parzen.fit(X_train, y_train)
plot_decision_boundary(clf_parzen, X_test, y_test, title=f"Parzen Window Classifier (h={best_h_parzen})", class_labels=[0, 1])

# %%
# Визуализация границы принятия решений для метода потенциальных функций
clf_pot = PotentialFunctionClassifier(h=best_h_pot, epochs=best_epochs_pot)
clf_pot.fit(X_train, y_train)

plot_decision_boundary(clf_pot, X_test, y_test, title=f"Potential Functions Classifier (h={best_h_pot}, epochs={best_epochs_pot})", class_labels=[0, 1])
