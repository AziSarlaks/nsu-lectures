# %%
#1
"""На вход программе подаётся число n – количество собачьих лет. Напишите программу, которая вычисляет возраст собаки в человеческих годах 
по следующему алгоритму: в течение первых двух лет собачий год равен 10.5 человеческим годам, 
после этого каждый год собаки равен 4 человеческим годам."""

# %%
# Напишите Ваш код здесь
n = int(input())
sum = 0
for i in range(1, n+1):
    if i <= 2:
        sum += 10.5
    else:
        sum += 4
print(sum)
# Out:
# 25.0

# %%
#2
"""На вход программе подаются три строки: имя, фамилия и отчество (именно в таком порядке). Напишите программу, которая выводит инициалы человека."""

# %%
# Напишите Ваш код здесь
print(f"{input().upper()[0]}. {input().upper()[0]}. {input().upper()[0]}.")
# Out:
# А. П. А.

# %%
#3
"""Используя срезы, дополните приведённый ниже код так, чтобы он вывел 
1) первые 12 символов строки
2) последние 9 символов строки 
3) каждый 7 символ строки
4) вывел строку в обратном порядке
Строка: In 2010, someone paid 10k Bitcoin for two pizzas."""

# %%
s = "In 2010, someone paid 10k Bitcoin for two pizzas."
# Напишите Ваш код здесь
print(s[:12])
print(s[-9:])
print(s[6], s[13], s[20], s[27], s[34], s[41], s[48])
print(s[::-1])
# Out:
# In 2010, som
# o pizzas.
# 0 o d i f   .
# .sazzip owt rof nioctiB k01 diap enoemos ,0102 nI

# %%
#4
"""На вход программе подаётся одно слово, записанное в нижнем регистре. Напишите программу, которая определяет, является ли оно палиндромом.
Палиндром слово которео читается одинако слева на право и наоборот, шалаш - палиндром"""

# %%
# Напишите Ваш код здесь
x = input()
print("YES" if x == x[::-1] else "NO")
# Out:
# NO

# %%
#5
"""На вход программе подаётся одна строка. Напишите программу, которая выводит:

1. общее количество символов в строке;
2. исходную строку, повторённую 3 раза;
3. первый символ строки;
4. первые три символа строки;
5. последние три символа строки;
6. строку в обратном порядке;
7. строку с удалённым первым и последним символами.

# %%
# Напишите Ваш код здесь
x = input()
print(len(x))
print(x*3)
print(x[0])
print(x[:3])
print(x[-3:])
print(x[::-1])
print(x[1:-1])
# Out:
# 5
# 123451234512345
# 1
# 123
# 345
# 54321
# 234

# %%
#6
"""На вход программе подаётся строка текста. Напишите программу, которая разрежет её на две равные части, переставит их местами и выведет на экран.
Если длина строки нечётная, то длина первой части должна быть на один символ больше."""

# %%
# Напишите Ваш код здесь
x = input()
if len(x)%2 != 0:
    print(x[len(x)//2+1:] + x[0:len(x)//2+1])
else:
    print(x[len(x)//2:] + x[0:len(x)//2])
# Out:
# 45123
