# %%
#Attributes and methods

# %%
#1
"""Саша учится программировать и решил создать класс, описывающий его машину и вывести на экран её цвет.
Задание:
Создайте класс Car.
Объявите (создайте) атрибут color внутри класса, со значением "blue".
Выведите на экран значение атрибута color. """

# %%
# Enter your code here
class Car:
    color = "blue"
print(Car.color)
# Out:
# blue

# %%
#2
"""Саша наконец-то смог заниматься по 2 часа без перерыва и решил продемонстрировать свои знания перед Машенькой.
Он попросил у неё учебник по математике, чтобы решить задачку, используя классы.

Задание:
Создайте класс Number и два атрибута: num1 и num2, со значениями 5 и 10 соответственно.
Выведите на экран сумму значений этих атрибутов, используя обращения к атрибутам. """

# %%
# Enter your code here
class Number:
    num1 = 5
    num2 = 10
print(Number.num1 + Number.num2)
# Out:
# 15

# %%
#3
"""Саша продвинулся в программировании и решил создать небольшую соцсеть и назвал её Person. 
Помогите Саше создать его первый аккаунт id_1.

Задание:
Создайте класс Person
Создайте атрибут name внутри класса, и присвойте ему значение "Sasha"
Создайте экземпляр класса и назовите его id_1. Не забывайте про скобки у класса.
Выведите на экран значение атрибута name, который принадлежит экземпляру id_1."""

# %%
# Enter your code here
class Person:
    name = "Sasha"
id_1 = Person()
print(id_1.name)
# Out:
# Sasha

# %%
#4
"""Параллельно с соцсетью, Саша потихоньку разрабатывает GPS навигатор и решил протестировать изменение координат, используя классы.

Задание:
Создайте пустой класс Сoordinate.
Создайте экземпляр coord класса Сoordinate.
Создайте атрибут "x" в экземпляре coord, со значением 100.
Измените атрибут "x"  в экземпляре coord на число 5.
Выведите на экран значение атрибута "x" экземпляра coord, с помощью print."""

# %%
# Enter your code here
class Coordinate:
    pass
coord = Coordinate()
coord.x = 100
coord.x = 5
print(coord.x)
# Out:
# 5

# %%
#5
"""Создайте свою анкету. 
Создайте класс, внитри него атрибуты:
    music = 'любимая песня, или группа, или стиль музыки'
    ufo = 'верите ли вы в нло?'
    film = 'ваш любимый фильм за последнее время или за всё время'
    what = 'что хотите делать с помощью программирования?'
    
    Можете добавить что-то своё, если хотите

Далее создайте экземпляр(ы) класса и напишите ответы на вопросы
Потом объедините ответы, список, словарь, коржеж.."""

# %%
# Enter your code here
class Questionnaire:
    music = 'pop'
    ufo = 'nope'
    film = 'Social Network'
    what = 'develop AI applications'

response = Questionnaire()
answers = {
    'music': response.music,
    'ufo': response.ufo,
    'film': response.film,
    'what': response.what
}
print(answers)
# Out:
# {'music': 'pop', 'ufo': 'nope', 'film': 'Social Network', 'what': 'develop AI applications'}

# %%
#6
"""Саша тестирует новый способ быстро создавать или изменять страничку пользователя, в его новой соцсети Person. 
Пользователь заполняет различные поля, и по окончании нажимает иконку "сохранить", после чего создаётся страничка с заполненными полями. 
Для этого он использует список, циклы и функцию setattr(). Помогите Саше протестировать этот новый способ.

Задание:
Создайте класс Person и объявите внутри класса атрибут setup со значением ['set_name', 'set_age', 'set_work', 'set_study'].
Создайте экземпляр id_1 от класса Person (не забываем скобки).
С помощью цикла for пройдите по атрибуту setup (используйте setup через id_1). Затем, с помощью функции setattr(), 
создайте 4 атрибута с именами взятыми из setup, а значения каждого атрибута будет создавать пользователь, поэтому используйте input()
в функции setattr().
Часть кода уже написана, вам нужно лишь выполнить задания выше.

# %%
# Enter your code here
class Person:
    setup = ['set_name', 'set_age', 'set_work', 'set_study']
id_1 = Person()
for value in id_1.setup:
    setattr(id_1, value, input())


# код ниже пожалуйста не удаляйте:
for value in id_1.setup:
    print(getattr(id_1, value))
# Out:
# Azi
# 18
# -
# NSU

# %%
#7
"""Саша тестирует новую функцию своей соцсети Person, а именно, ограничение количества друзей, 
которых могут видеть другие пользователи. Для этого он использует новую функцию delattr(). 
Помогите Саше скрыть определённых друзей, чтобы их не видели другие пользователи.  

Задание
Часть кода уже написана. Переменная names содержит список имён.
Проверить, есть ли в списке names имена атрибутов класса Person.
Если имя в списке и имя атрибута в классе совпадают, удалите атрибут из класса."""

# %%
names = ['Klementina', 'Roza', 'Balu', 'Lena', 'Leonid']  # список имён

class Person:
    Sasha = ''
    Masha = ''
    Lena = ''
    Leonid = ''

# ниже ваш код:

for name in names:
    if hasattr(Person, name):
        delattr(Person, name)

# строки ниже не удаляйте, ради вселенной:
print(len(Person.__dict__))
# Out:
# 6

# %%
#8
"""Машенька любит смотреть мультфильм Симпсоны. 
И однажды, она решила написать письмо любимым персонажам, начиная со строк: "Привет, Bart". 
И так к каждому персонажу. Помогите Машеньке написать начало. 

Задание:
Создайте метод и назовите его как пожелаете. Помните, что имя метода означает - глагол, действие, поэтому подберите соответствующее название.
Метод выводит на экран надпись: "Привет, атрибут". 
Но слово "атрибут" замените, на значение атрибута name у экземпляров. 
У каждого экземпляра свой атрибут name, поэтому и сообщения будут выводиться разными. 
Подсказка, можно использовать f-строку и не забудьте self.
Вызовите метод у каждого экземпляра. 
Вывод:
Привет, Bart
Привет, Lisa
Привет, Homer    """

# %%
class Simpsons:
    name = 'Simpsons'
    def greet(self):
        print(f'Привет, {self.name}')
    

bart = Simpsons()
lisa = Simpsons()
homer = Simpsons()

bart.name = 'Bart'
lisa.name = 'Lisa'
homer.name = 'Homer'

# здесь будет ваш код вызова метода:
bart.greet()
lisa.greet()
homer.greet()
# Out:
# Привет, Bart
# Привет, Lisa
# Привет, Homer

# %%
#9
"""Создайте класс. Создайте метод класса. В скобках метода укажите три параметра: (cls, x, y).
Метод создаёт атрибуты x и y в классе, со значениями параметров x и y соответственно. Например cls.x = x. 
Метод также выполняет умножение x на y, и выводит на экран результат с помощью print().
Вызовите метод через класс, и укажите в аргументах число 5 и 20. Например Класс.метод(5, 20). При вызове не нужно использовать print."""

# %%
# Enter your code here
class Coordinate:
    @classmethod
    def set_coordinates(cls, x, y):
        cls.x = x
        cls.y = y
        print(x * y)

Coordinate.set_coordinates(5, 20)
# Out:
# 100

# %%
#10
"""Саша подарил Машеньке карточку от MagicBank, с помощью которой можно делать покупки до 1000. 
Сделав покупку, карточка магическим образом снова пополняется до 1000.

Задание:
Создайте класс MagicBank и объявите внутри класса атрибут money = 1000.
Создайте метод класса add_money(cls). Метод изменяет значение атрибута класса money, и делает его равным 1000. 
Затем выводит на экран текст: Ваш счёт снова равен 1000. В print() используйте end='\n\n'.
Создайте метод класса reduce_money(cls, amount). С помощью этого метода мы осуществляем проверку, покупку и магическое пополнение. 
Параметр amount - это сумма покупки. Мы не можем осуществить покупку больше чем на 1000 за один раз, поэтому сделайте в методе вот что:
- Если amount больше 1000, выведите на экран текст: Нельзя тратить больше 1000 за один раз
- Иначе, выведите на экран: Покупка на сумму amount осуществлена. Например, "Покупка на сумму 500 осуществлена".
- Теперь нам нужно магически сделать наш счёт равным 1000. Для этого, вызываем метод  add_money() в блоке иначе. 
  Сделать это можно с помощью cls.add_money()."""

# %%
# Enter your code here
class MagicBank:
    money = 1000

    @classmethod
    def add_money(cls):
        cls.money = 1000
        print("Ваш счёт снова равен 1000.", end='\n\n')

    @classmethod
    def reduce_money(cls, amount):
        if amount > 1000:
            print("Нельзя тратить больше 1000 за один раз")
        else:
            print(f"Покупка на сумму {amount} осуществлена.")
            cls.add_money()

# код ниже пожалуйста не удаляйте 
masha = MagicBank()
masha.reduce_money(100)
masha.reduce_money(999)
masha.reduce_money(1000000000)
# Out:
# Покупка на сумму 100 осуществлена.
# Ваш счёт снова равен 1000.
#
# Покупка на сумму 999 осуществлена.
# Ваш счёт снова равен 1000.
#
# Нельзя тратить больше 1000 за один раз

# %%
#11
"""Саша узнал про __dict__  по телевизору, когда смотрел передачу "В мире python".
Решил попробовать вывести __dict__ экземпляра, но пока не понял как. Помогите Саше вывести информацию о __dict__.

Задание:
Выведите на экран __dict__ экземпляра my с помощью print."""

# %%
# Enter your code here
my = Car()
print((my.__dict__))
# Out:
# {}

# %%
#12
"""Саша научился с помощью __dict__ быстро добавлять группы людей в своей соцсети Person. 
Теперь ему нужно быстрым способом увидеть список всех друзей, нажав на одну кнопку.
Пока он думает использовать цикл и __dict__. 

Задание:
Часть кода уже написана.
Выведите на экран, значения всех атрибутов экземпляра person1. 
Каждое значение должно быть на отдельной строчке. 
Можете сделать простым способом, а можете попробовать через цикл, в любом случае используйте __dict__. """

# %%
class Person:
    pass

person_1 = Person()
person_1.__dict__ = {'name': 'Sasha', 'age': '20', 'work': 'scientist'}

# ваш код ниже:
for value in person_1.__dict__.values():
    print(value)
# Out:
# Sasha
# 20
# scientist

# %%
#13
"""Саша улучшает свою соцсеть Person. 
При создании странички, пользователь указывает обязательные данные, и нажимая на кнопку "создать", создаётся страница с данными пользователя.

Задание:
Создайте класс Person.
Объявите метод __init__ , который создаёт в экземпляре 4 атрибута: name, age, study, work. 
В скобках __init__ укажите 4 параметра с теми же именами, что и у атрибутов. И не забудьте про self.
Если бы я создавал атрибут name, я бы сделал вот так: self.name = name. 
Создайте экземпляр класса id_1 и укажите в скобках Person() вот такие аргументы: 'Sasha', 22, 'college', 'developer'
Выведите на экран __dict__ экземпляра id_1."""

# %%
# Enter your code here
class Person:
    def __init__(self, name, age, study, work):
        self.name = name
        self.age = age
        self.study = study
        self.work = work
id_1 = Person('Sasha', 22, 'college', 'developer')
print((id_1.__dict__))
# Out:
# {'name': 'Sasha', 'age': 22, 'study': 'college', 'work': 'developer'}

# %%
#14
"""Саша разрабатывает 2D игру "Крафтляндия".
По условиям игры, в определённых местах будут строиться объекты. 
Игрок сам выбирает место и строит там объект. 
Двигая мышкой, мы передвигаемся по координатной плоскости и строим объекты в определённых координатах. 
В одних местах можно делать постройки, а в других нельзя, поэтому нужно создать проверку координат.
Саша использует __init__ при создании постройки и метод check_build(), который проверяет координаты, перед строительством объекта.
Постройками будут наши экземпляры.

Задание:
Часть кода уже готова.
В методе __init__ нужно вызвать метод check_build() с аргументами x, y
В методе check_build() мы делаем проверку:
- Если x равен числам 1, 200, 500, 1920 или y равен числам 1, 300, 600, 1080, то выводим на экран:
Объект в этом месте невозможен
- Иначе выводим на экран: Объект построен
Всё остальное готово, выполните лишь то, что написано в задании."""

# %%
# Enter your code here
class Buildings:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.check_build(x, y)

    def check_build(self, x, y):
        if x in [1, 200, 500, 1920] or y in [1, 300, 600, 1080]:
            print("Объект в этом месте невозможен")
        else:
            print("Объект построен")


# код ниже пожалуйста не удаляйте
kitchen = Buildings(20, 800)
living_room = Buildings(400, 500)
garage = Buildings(900, 600)
forge = Buildings(1920, 280)
dining_room = Buildings(300, 500)
# Out:
# Объект построен
# Объект построен
# Объект в этом месте невозможен
# Объект в этом месте невозможен
# Объект построен

# %%
#15
"""
Создайте класс Homer.
Создайте в классе Homer метод __init__(self, name), который создает атрибут name.
Создайте пустой класс Daughter и сделайте его дочерним классом для Homer. Используйте pass для пустого класса.
Создайте экземпляр daughter1 для класса Daughter и присвойте атрибуту name значение Lisa.
Выведите на экран значение атрибута name через экземпляр daughter1.
"""

# %%
# Enter your code here
class Homer:
    def __init__(self, name):
        self.name = name
class Daughter(Homer):
    pass
daughter1 = Daughter('Lisa')
print(daughter1.name)
# Out:
# Lisa

# %%
#16
"""
Создайте два класса Minecraft и Roblox. Класс Roblox - будет дочерним классом Minecraft.
В классе Minecraft создайте метод hello_creeper, который будет выводить на экран фразу - "Hello, Creeper!".
В классе Roblox создайте метод hello_all, который будет вызывать метод hello_сreeper. 
Метод hello_all также будет выводить на экран фразу "Hello, Pozzy!" с помощью print.
Создайте экземпляр hello класса Roblox.
Вызовите метод hello_all, через экземпляр hello. Функцию print не нужно использовать.
В итоге, программа будет выводить на экран две фразы, как указано в примере ниже. 

Hello, Creeper!
Hello, Pozzy! 
"""

# %%
# Enter your code here
class Minecraft:
    def hello_creeper(self):
        print("Hello, Creeper!")
class Roblox(Minecraft):
    def hello_all(self):
        self.hello_creeper()
        print("Hello, Pozzy!")
hello = Roblox()
hello.hello_all()
# Out:
# Hello, Creeper!
# Hello, Pozzy!

# %%
#17
"""
Создайте три класса King, Queen, Prince. Класс Prince наследуется от (King, Queen).
В классе King создайте атрибут "a" равный 4. В классе Queen создайте атрибут "b" равный 6. В классе Prince создайте атрибут "c" равный 10.
Создайте экземпляр count от класса Prince.
Выведите на экран результат сложения атрибутов "a" и "b" и "c", через экземпляр count (т.е. count.a + ...)
"""

# %%
# Enter your code here
class King:
    a = 4
class Queen:
    b = 6
class Prince(King, Queen):
    c = 10
count = Prince()
print(count.a + count.b + count.c)
# Out:
# 20

# %%
#18
"""
Создайте класс Number и объявите в нём два метода: __init__ и  __delattr__.
Метод __init__:
- содержит параметры (self, a, b)
- создаёт атрибуты a, b и присваивает в них параметры a, b соответственно.
- создаёт атрибут s который равен сумме a + b
- удаляет атрибут s
Метод __delattr__ :
- содержит параметры (self, name)
- содержит условие, если атрибут s больше 10, то ничего не делаем (pass).
Иначе производим стандартное удаление с помощью super().__delattr__(name)
Код проверки не удаляйте, пожалуйста.
"""

# %%
# Enter your code here
class Number:
    def __init__(self, a, b):
        self.a = a
        self.b = b
        self.s = a + b
        del self.s

    def __delattr__(self, name):
        if hasattr(self, 's') and self.s > 10:
            pass
        else:
            super().__delattr__(name)

# код проверки:
number1 = Number(4, 5)
print('s' in number1.__dict__)

number2 = Number(6, 11)
print('s' in number2.__dict__)
# Out:
# False
# True

# %%
#19
"""
Создайте класс Bank
Объявите три метода: __init__, print_balance, change_balance
Метод __init__ имеет три параметра:  имя клиента, номер карты и баланс, и создаёт три приватных атрибута. 
Имена параметрам и атрибутам придумайте сами.
Метод print_balance является обычным методом, и выводит на экран баланс клиента с помощью print().
Метод change_balance имеет параметр (self, money), и изменяет баланс клиента. 
Если money отрицательное, то баланс уменьшается, если money положительное, то баланс увеличивается.
Метод только изменяет атрибут связанный с балансом.
Часть кода уже написана, вам нужно лишь сделать то, что написано выше.
"""

# %%
# Enter your code here
class Bank:
    def __init__(self, client_name, card_number, balance):
        self.__client_name = client_name
        self.__card_number = card_number
        self.__balance = balance

    def print_balance(self):
        print(self.__balance)

    def change_balance(self, money):
        self.__balance += money

# код ниже пожалуйста не меняйте
id_1 = Bank('Sasha', 12345678, 500)
id_1.change_balance(-500)
id_1.print_balance()
# Out:
# 0
