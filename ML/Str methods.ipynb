# %%
# Метод capitalize() - возвращает копию строки s,
# в которой первый символ имеет верхний регистр, а все остальные символы имеют нижний регистр
s = 'foO BaR BAZ quX'
print(s.capitalize())
# Out:
# Foo bar baz qux

# %%
#Метод swapcase() возвращает копию строки s, 
#в которой все символы, имеющие верхний регистр, преобразуются в символы нижнего регистра и наоборот.
s = 'FOO Bar 123 baz qUX'
print(s.swapcase())
# Out:
# foo bAR 123 BAZ Qux

# %%
#Метод title() возвращает копию строки s, в которой первый символ каждого слова переводится в верхний регистр.
s = 'the sun also rises'
print(s.title())
# Out:
# The Sun Also Rises

# %%
#Метод lower() возвращает копию строки s, в которой все символы имеют нижний регистр.
s = 'FOO Bar 123 baz qUX'
print(s.lower())
# Out:
# foo bar 123 baz qux

# %%
#Метод upper() возвращает копию строки s, в которой все символы имеют верхний регистр.
s = 'FOO Bar 123 baz qUX'
print(s.upper())
# Out:
# FOO BAR 123 BAZ QUX

# %%
#Метод count(<sub>, <start>, <end>) считает количество непересекающихся вхождений подстроки <sub> 
#в исходную строку s.
s = 'foo goo moo'
print(s.count('oo'))
print(s.count('oo', 0, 8))  # подсчет с 0 по 7 символ
# Out:
# 3
# 2

# %%
#Метод startswith(<prefix>, <start>, <end>) определяет, начинается ли исходная строка s подстрокой <prefix>. 
#Метод возвращает значение True, если исходная строка начинается с подстроки <prefix>, 
#или False в противном случае.
s = 'foobar'
print(s.startswith('foo'))
print(s.startswith('baz'))
# Out:
# True
# False

# %%
#Метод endswith(<suffix>, <start>, <end>) определяет, оканчивается ли исходная строка s 
#подстрокой <suffix>. Метод возвращает значение True, 
#если исходная строка оканчивается на подстроку <suffix>, или False в противном случае.
s = 'foobar'
print(s.endswith('bar'))
print(s.endswith('baz'))
# Out:
# True
# False

# %%
#Метод find(<sub>, <start>, <end>) находит индекс первого вхождения подстроки <sub> в исходной строке s.
#Если строка s не содержит подстроки <sub>, то метод возвращает значение -1.
#Мы можем использовать данный метод наравне с оператором in для проверки: содержит ли заданная
#строка некоторую подстроку или нет.
s = 'foo bar foo baz foo qux'
print(s.find('foo'))
print(s.find('bar'))
print(s.find('qu'))
print(s.find('python'))


#Метод index(<sub>, <start>, <end>) идентичен методу find(<sub>, <start>, <end>), за тем исключением, 
#что он вызывает ошибку ValueError: substring not found во время выполнения программы, 
#если подстрока <sub> не найдена.
# Out:
# 0
# 4
# 20
# -1

# %%
#Метод strip() возвращает копию строки s, у которой удалены все пробелы, стоящие в начале и конце строки.
s = '     foo bar foo baz foo qux      '
print(s.strip())
# Out:
# foo bar foo baz foo qux

# %%
#Метод lstrip() возвращает копию строки s, у которой удалены все пробелы, стоящие в начале строки.
s = '     foo bar foo baz foo qux      '
print(s.lstrip())
# Out:
# foo bar foo baz foo qux

# %%
#Метод rstrip() возвращает копию строки s, у которой удалены все пробелы, стоящие в конце строки.
s = '      foo bar foo baz foo qux      '
print(s.rstrip())
# Out:
#       foo bar foo baz foo qux

# %%
#Метод replace(<old>, <new>) возвращает копию s со всеми вхождениями подстроки <old>, заменёнными на <new>.
s = 'foo bar foo baz foo qux'
print(s.replace('foo', 'grault'))
print(s.replace('foo', 'grault', 2))
# Out:
# grault bar grault baz grault qux
# grault bar grault baz foo qux

# %%
#Метод isalnum() определяет, состоит ли исходная строка из буквенно-цифровых символов. 
#Метод возвращает значение True, если исходная строка является непустой и состоит только 
#из буквенно-цифровых символов, или False в противном случае.
s1 = 'abc123'
s2 = 'abc$*123'
s3 = ''
print(s1.isalnum())
print(s2.isalnum())
print(s3.isalnum())
# Out:
# True
# False
# False

# %%
#Метод isalpha() определяет, состоит ли исходная строка из буквенных символов.
#Метод возвращает значение True, если исходная строка является непустой и состоит только 
#из буквенных символов, или False в противном случае.
s1 = 'ABCabc'
s2 = 'abc123'
s3 = ''
print(s1.isalpha())
print(s2.isalpha())
print(s3.isalpha())
# Out:
# True
# False
# False

# %%
#Метод isdigit() определяет, состоит ли исходная строка только из цифровых символов. 
#Метод возвращает значение True, если исходная строка является непустой и состоит только из 
#цифровых символов, или False в противном случае.
s1 = '1234567'
s2 = 'abc123'
s3 = ''
print(s1.isdigit())
print(s2.isdigit())
print(s3.isdigit())
# Out:
# True
# False
# False

# %%
#Метод islower() определяет, являются ли все буквенные символы исходной строки строчными
#(имеют нижний регистр). Метод возвращает значение True, если все буквенные символы исходной
#строки являются строчными, или False в противном случае.
s1 = 'abc'
s2 = 'abc1$d'
s3 = 'Abc1$D'
print(s1.islower())
print(s2.islower())
print(s3.islower())


#Метод isupper() наоборот
# Out:
# True
# True
# False

# %%
#Метод isspace() определяет, состоит ли исходная строка только из пробельных символов. 
#Метод возвращает значение True, если строка состоит только из пробельных символов, 
#или False в противном случае.
s1 = '       '
s2 = 'abc1$d'
print(s1.isspace())
print(s2.isspace())
# Out:
# True
# False

# %%
# старый стиль

# %%
name = "Alex"
age = 25
print("Name: %s, Age: %d" %(name,age))
# Out:
# Name: Alex, Age: 25

# %%
# Метод format

# %%
name = "Alex"
age = 25
print("Name: {}, Age: {}".format(name,age))
print("Age: {1}, Name: {0}".format(name,age))
# Out:
# Name: Alex, Age: 25
# Age: 25, Name: Alex

# %%
# f - строки

# %%
name = "Alex"
age = 25
print(f"Name: {name}, Age: {age}")
# Out:
# Name: Alex, Age: 25
